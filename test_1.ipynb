# %%
import numpy as np
import matplotlib.pyplot as plt




data_1 = np.loadtxt("output_test_case_1xy.csv", delimiter=',')
plt.plot(data_1[:,0],data_1[:,1],linestyle=":", color='r')

plt.xlabel("x")
plt.ylabel("y")


plt.savefig("test_case_1.png")

# %%
import numpy as np
import matplotlib.pyplot as plt

data_1 = np.loadtxt("output_test_case_2xy.csv", delimiter=',')
plt.plot(data_1[:,0],data_1[:,1],linestyle=":", color='r',label = 'b=1')

plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')
